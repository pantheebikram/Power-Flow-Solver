# %%
# import necessary libaries and data files
import numpy as np
from data import datas
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#load data and manupulate datas if needed
bus_data, line_data, load_data, gen_data, wind_data = datas() #data loading

line_data = pd.DataFrame(line_data).sort_values(by=[0,1]).values #line data sorting and data type change

bus_data = pd.DataFrame(bus_data).sort_values(by = [0]).values #Bus data sorting and data type change

load_data = pd.DataFrame(load_data).sort_values(by = [0]).astype({0:'int'}).set_index(0) #Load data sorting and data type change

gen_data = pd.DataFrame(gen_data).sort_values(by = [0]).astype({0:'int'}).set_index(0) #Generation data sorting and data type change

wind_data = pd.DataFrame(wind_data).sort_values(by = [0]).astype({0:'int'}).set_index(0) #Wind Generation data sorting and data type change

# %%
base_mva = 100
R = line_data[:, 2]
X = line_data[:, 3]
B = 0.5j * line_data[:, 4]
taps = line_data[:,5]
Bsh = 1j* bus_data[:, 3]
Z = R + 1j * X
Y = 1 / Z
nline = len(line_data[:, 0])
nbus = int(np.amax(line_data[:, :2]))  # Total Number of buses

# %%
def tap_handle(x):
    if np.real(x) == 0:
        return 1
    else:
        return complex(x)
    
# Y Bus Formation
def Y_bus():
    Ybus = np.zeros((nbus, nbus), dtype=complex)
    Y1 = np.zeros((73, 73), dtype=complex)
    np.fill_diagonal(Y1,Bsh)
    
    for k in range(nline):
        # Off Diagonal Elements
        Ybus[int(line_data[k, 0]) - 1, int(line_data[k, 1]) - 1] -= (Y[k])/np.conj(tap_handle(taps[k]))
        Ybus[int(line_data[k, 1]) - 1, int(line_data[k, 0]) - 1] -= (Y[k])/tap_handle(taps[k])

        # Diagonal Elements
        Ybus[int(line_data[k, 0]) - 1, int(line_data[k, 0]) - 1] += (Y[k] + B[k])/pow(abs(tap_handle(taps[k])),2)
        Ybus[int(line_data[k, 1]) - 1, int(line_data[k, 1]) - 1] += Y[k] + B[k]
    
    Y_bus_ = Ybus + Y1
    return Y_bus_

# %%
#From Bus Data
bus_no = bus_data[:, 0].astype(int)
bus_type = bus_data[:,1].astype(int)

#From Load Data
pl = np.zeros(nbus)
pf = np.zeros(nbus)
delta = np.zeros(nbus)
for k in load_data.index:
    pl[k-1] = load_data.loc[k, 2]/base_mva #base power
    pf[k-1] = load_data.loc[k, 1]
ql = pl * np.tan(np.arccos(pf))

#From Generation Data
pg_ = np.zeros(nbus)
qg = np.zeros(nbus)
vmag = np.ones(nbus)
qmin = np.zeros(nbus)
qmax = np.zeros(nbus)
for k in gen_data.index:
    pg_[k-1] = (gen_data.loc[k, 4]).sum()/base_mva
    vmag[k-1] = np.mean(gen_data.loc[k, 3])
    qmin[k-1] = gen_data.loc[k, 2].sum()
    qmax[k-1] = gen_data.loc[k, 1].sum()

# From Wind Data
pwg = np.zeros(nbus)
for k in wind_data.index:
    pwg[k-1] = (wind_data.loc[k, 4])/base_mva

pg = pg_ + pwg
b_data = pd.DataFrame()
b_data['Bus_No'] = bus_no
b_data['Bus_type'] = bus_type
b_data['Pg'] = pg
b_data['Qg'] = qg
b_data['Pl'] = pl
b_data['Ql'] = ql
b_data['Vmag'] = vmag
b_data['Delta'] = delta
b_data['Qmin'] = qmin/base_mva
b_data['Qmax'] = qmax/base_mva
b_data['Vr'] = vmag * np.cos(delta)
b_data['Vm'] = vmag * np.sin(delta)
b_data = b_data.set_index('Bus_No')
b_data.head()
# Out:
#         Bus_type      Pg   Qg      Pl        Ql   Vmag  Delta  Qmin  Qmax  \
# Bus_No
# 1              2  0.5282  0.0  0.5635  0.114718  1.035    0.0  -0.5   0.8
# 2              1  0.0000  0.0  0.5041  0.103934  1.035    0.0  -0.5   0.8
# 3              1  0.0000  0.0  0.9342  0.192128  1.000    0.0   0.0   0.0
# 4              1  0.0000  0.0  0.3855  0.078077  1.000    0.0   0.0   0.0
# 5              1  0.0000  0.0  0.3707  0.073113  1.000    0.0   0.0   0.0
#
#            Vr   Vm
# Bus_No
# 1       1.035  0.0
# 2       1.035  0.0
# 3       1.000  0.0
# 4       1.000  0.0
# 5       1.000  0.0

# %%
def d_Ir_Vr(Vr, Vm, P, Q):
    V = pow(Vr,2) + pow(Vm,2)
    return (P* (pow(Vm, 2) - pow(Vr, 2)) - 2*Q*Vr*Vm)/pow(V,2)

def d_Ir_Vm(Vr, Vm, P, Q):
    V = pow(Vr,2) + pow(Vm,2)
    return (Q* (pow(Vr, 2) - pow(Vm, 2)) - 2*P*Vr*Vm)/pow(V,2)

def d_Im_Vr(Vr, Vm, P, Q):
    V = pow(Vr,2) + pow(Vm,2)
    return (Q* (pow(Vr, 2) - pow(Vm, 2)) - 2*P*Vr*Vm)/pow(V,2)

def d_Im_Vm(Vr, Vm, P, Q):
    V = pow(Vr,2) + pow(Vm,2)
    return (P* (pow(Vr, 2) - pow(Vm, 2)) - 2*Q*Vr*Vm)/pow(V,2)

def d_Ir_Q(Vr, Vm):
    V = pow(Vr,2) + pow(Vm,2)
    return Vm/pow(V,2)

def d_Im_Q(Vr, Vm):
    V = pow(Vr,2) + pow(Vm,2)
    return -Vr/pow(V,2)

# %%
def data_df(b_data_):
    b_df = b_data_
    b_df['Psh'] = b_data['Pg'] - b_data['Pl']
    b_df['Qsh'] = b_data['Qg'] - b_data['Ql']
    b_df['Ir'] = (b_df['Psh']*b_df['Vr'] + b_df['Qsh']*b_df['Vm'])/(pow(b_df['Vr'], 2) + pow(b_df['Vm'], 2))
    b_df['Im'] = (b_df['Psh']*b_df['Vm'] - b_df['Qsh']*b_df['Vr'])/(pow(b_df['Vr'], 2) + pow(b_df['Vm'], 2))
    b_df['d_Ir_Vr'] = d_Ir_Vr(b_df['Vr'],b_df['Vm'], b_df['Psh'],b_df['Qsh'])
    b_df['d_Ir_Vm'] = d_Ir_Vm(b_df['Vr'],b_df['Vm'], b_df['Psh'],b_df['Qsh'])
    b_df['d_Im_Vr'] = d_Im_Vr(b_df['Vr'],b_df['Vm'], b_df['Psh'],b_df['Qsh'])
    b_df['d_Im_Vm'] = d_Ir_Vm(b_df['Vr'],b_df['Vm'], b_df['Psh'],b_df['Qsh'])
    b_df['d_Ir_Q']  = d_Ir_Q(b_df['Vr'],b_df['Vm'])
    b_df['d_Im_Q']  = d_Im_Q(b_df['Vr'],b_df['Vm'])


    con_pv = (b_df['Bus_type'] == 2) # Condition for PV Bus
    con_pq = (b_df['Bus_type'] == 1)
    b_df.loc[con_pq,'IR_k'] = (- b_df.loc[con_pq,'d_Ir_Vr']*b_df.loc[con_pq,'Vr'] - 
                                   b_df.loc[con_pq,'d_Ir_Vm']*b_df.loc[con_pq,'Vm'] + b_df.loc[con_pq,'Ir'])
    b_df.loc[con_pq,'IM_k'] = (- b_df.loc[con_pq,'d_Im_Vr']*b_df.loc[con_pq,'Vr'] - 
                                   b_df.loc[con_pq,'d_Im_Vm']*b_df.loc[con_pq,'Vm'] + b_df.loc[con_pq,'Im'])

    b_df.loc[con_pv,'IR_k'] = (- b_df.loc[con_pv,'d_Ir_Vr']*b_df.loc[con_pv,'Vr'] - 
                                   b_df.loc[con_pv,'d_Ir_Vm']*b_df.loc[con_pv,'Vm'] - 
                                   b_df.loc[con_pv,'d_Ir_Q']*b_df.loc[con_pv,'Qsh'] + b_df.loc[con_pv,'Ir'])
    b_df.loc[con_pv,'IM_k'] = (- b_df.loc[con_pv,'d_Im_Vr']*b_df.loc[con_pv,'Vr'] - 
                                   b_df.loc[con_pv,'d_Im_Vm']*b_df.loc[con_pv,'Vm'] - 
                                   b_df.loc[con_pv,'d_Im_Q']*b_df.loc[con_pv,'Qsh'] + b_df.loc[con_pv,'Im'])

    return b_df

# %%
data_df(b_data)
# Out:
#         Bus_type      Pg   Qg      Pl        Ql   Vmag  Delta  Qmin  Qmax  \
# Bus_No
# 1              2  0.5282  0.0  0.5635  0.114718  1.035    0.0 -0.50  0.80
# 2              1  0.0000  0.0  0.5041  0.103934  1.035    0.0 -0.50  0.80
# 3              1  0.0000  0.0  0.9342  0.192128  1.000    0.0  0.00  0.00
# 4              1  0.0000  0.0  0.3855  0.078077  1.000    0.0  0.00  0.00
# 5              1  0.0000  0.0  0.3707  0.073113  1.000    0.0  0.00  0.00
# ...          ...     ...  ...     ...       ...    ...    ...   ...   ...
# 69             2  4.0000  0.0  0.0000  0.000000  1.050    0.0 -0.50  2.00
# 70             1  0.0000  0.0  0.0000  0.000000  1.050    0.0 -0.60  0.96
# 71             2  0.5424  0.0  0.0000  0.000000  1.050    0.0 -1.25  3.10
# 72             1  0.0000  0.0  0.0000  0.000000  1.000    0.0  0.00  0.00
# 73             1  0.0000  0.0  0.0000  0.000000  1.000    0.0  0.00  0.00
#
#            Vr  ...        Ir        Im   d_Ir_Vr   d_Ir_Vm   d_Im_Vr  \
# Bus_No         ...
# 1       1.035  ... -0.034106  0.110839  0.032953 -0.107091 -0.107091
# 2       1.035  ... -0.487053  0.100419  0.470583 -0.097023 -0.097023
# 3       1.000  ... -0.934200  0.192128  0.934200 -0.192128 -0.192128
# 4       1.000  ... -0.385500  0.078077  0.385500 -0.078077 -0.078077
# 5       1.000  ... -0.370700  0.073113  0.370700 -0.073113 -0.073113
# ...       ...  ...       ...       ...       ...       ...       ...
# 69      1.050  ...  3.809524  0.000000 -3.628118  0.000000  0.000000
# 70      1.050  ...  0.000000  0.000000 -0.000000  0.000000  0.000000
# 71      1.050  ...  0.516571  0.000000 -0.491973  0.000000  0.000000
# 72      1.000  ...  0.000000  0.000000 -0.000000  0.000000  0.000000
# 73      1.000  ...  0.000000  0.000000 -0.000000  0.000000  0.000000
#
#          d_Im_Vm  d_Ir_Q    d_Im_Q      IR_k      IM_k
# Bus_No
# 1      -0.107091     0.0 -0.901943 -0.068213  0.118208
# 2      -0.097023     0.0 -0.901943 -0.974106  0.200838
# 3      -0.192128     0.0 -1.000000 -1.868400  0.384256
# 4      -0.078077     0.0 -1.000000 -0.771000  0.156154
# 5      -0.073113     0.0 -1.000000 -0.741400  0.146226
# ...          ...     ...       ...       ...       ...
# 69      0.000000     0.0 -0.863838  7.619048  0.000000
# 70      0.000000     0.0 -0.863838  0.000000  0.000000
# 71      0.000000     0.0 -0.863838  1.033143  0.000000
# 72      0.000000     0.0 -1.000000  0.000000  0.000000
# 73      0.000000     0.0 -1.000000  0.000000  0.000000
#
# [73 rows x 23 columns]

# %%
'''def Jacobian(df, y_bus):
    b_df = data_df(df)
    G = np.real(y_bus)
    B = np.imag(y_bus)
    delta_I = np.zeros((nbus, 1, 3, 1))
    
    J = np.zeros((nbus, nbus, 3, 3))

    for i in b_df.index:
        for j in b_df.index:
            if b_df.loc[i,"Bus_type"] != 3:
                if b_df.loc[i,"Bus_type"] == 1: # For PQ Bus
                    if i == j:
                        J[i-1, j-1][0, 0] = -b_df.loc[i, 'd_Im_Vr'] + B[i-1, i-1]
                        J[i-1, j-1][0, 1] = -b_df.loc[i, 'd_Im_Vm'] + G[i-1, i-1]
                        J[i-1, j-1][1, 0] = -b_df.loc[i, 'd_Ir_Vr'] + G[i-1, i-1]
                        J[i-1, j-1][1, 1] = -b_df.loc[i, 'd_Ir_Vm'] - B[i-1, i-1]

                    else:
                        J[i-1, j-1][0, 0] =  B[i-1, j-1]
                        J[i-1, j-1][0, 1] =  G[i-1, j-1]
                        J[i-1, j-1][1, 0] =  G[i-1, j-1]
                        J[i-1, j-1][1, 1] =  -B[i-1, j-1]
                    
                    delta_I[i-1,0][0,0] = b_df.loc[i,'IR_k']
                    delta_I[i-1,0][1,0] = b_df.loc[i,'IM_k']
                   
                        
                else: #For PV Bus
                    if i == j:
                        J[i-1, j-1][0, 0] = -b_df.loc[i, 'd_Im_Vr'] + B[i-1, i-1]
                        J[i-1, j-1][0, 1] = -b_df.loc[i, 'd_Im_Vm'] + G[i-1, i-1]
                        J[i-1, j-1][1, 0] = -b_df.loc[i, 'd_Ir_Vr'] + G[i-1, i-1]
                        J[i-1, j-1][1, 1] = -b_df.loc[i, 'd_Ir_Vm'] - B[i-1, i-1]
                        J[i-1, j-1][0, 2] = -b_df.loc[i, 'd_Im_Q' ]
                        J[i-1, j-1][1, 2] = -b_df.loc[i, 'd_Ir_Q' ]
                        J[i-1, j-1][2, 0] = b_df.loc[i, 'Vr']
                        J[i-1, j-1][2, 1] = b_df.loc[i, 'Vm']
                    
                    else:
                        J[i-1, j-1][0, 0] =  B[i-1, j-1]
                        J[i-1, j-1][0, 1] =  G[i-1, j-1]
                        J[i-1, j-1][1, 0] =  G[i-1, j-1]
                        J[i-1, j-1][1, 1] =  -B[i-1, j-1]

                    delta_I[i-1,0][0,0] = b_df.loc[i,'IR_k']
                    delta_I[i-1,0][1,0] = b_df.loc[i,'IM_k']
                    delta_I[i-1,0][2,0] = pow(b_df.loc[i, 'Vmag'],2)
        
    return delta_I, J '''
# Out:
# 'def Jacobian(df, y_bus):\n    b_df = data_df(df)\n    G = np.real(y_bus)\n    B = np.imag(y_bus)\n    delta_I = np.zeros((nbus, 1, 3, 1))\n    \n    J = np.zeros((nbus, nbus, 3, 3))\n\n    for i in b_df.index:\n        for j in b_df.index:\n            if b_df.loc[i,"Bus_type"] != 3:\n                if b_df.loc[i,"Bus_type"] == 1: # For PQ Bus\n                    if i == j:\n                        J[i-1, j-1][0, 0] = -b_df.loc[i, \'d_Im_Vr\'] + B[i-1, i-1]\n                        J[i-1, j-1][0, 1] = -b_df.loc[i, \'d_Im_Vm\'] + G[i-1, i-1]\n                        J[i-1, j-1][1, 0] = -b_df.loc[i, \'d_Ir_Vr\'] + G[i-1, i-1]\n                        J[i-1, j-1][1, 1] = -b_df.loc[i, \'d_Ir_Vm\'] - B[i-1, i-1]\n\n                    else:\n                        J[i-1, j-1][0, 0] =  B[i-1, j-1]\n                        J[i-1, j-1][0, 1] =  G[i-1, j-1]\n                        J[i-1, j-1][1, 0] =  G[i-1, j-1]\n                        J[i-1, j-1][1, 1] =  -B[i-1, j-1]\n                    \n                    delta_I[i-1,0][0,0] = b_df.loc[i,\'IR_k\']\n                    delta_I[i-1,0][1,0] = b_df.loc[i,\'IM_k\']\n                   \n                        \n                else: #For PV Bus\n                    if i == j:\n                        J[i-1, j-1][0, 0] = -b_df.loc[i, \'d_Im_Vr\'] + B[i-1, i-1]\n                        J[i-1, j-1][0, 1] = -b_df.loc[i, \'d_Im_Vm\'] + G[i-1, i-1]\n                        J[i-1, j-1][1, 0] = -b_df.loc[i, \'d_Ir_Vr\'] + G[i-1, i-1]\n                        J[i-1, j-1][1, 1] = -b_df.loc[i, \'d_Ir_Vm\'] - B[i-1, i-1]\n                        J[i-1, j-1][0, 2] = -b_df.loc[i, \'d_Im_Q\' ]\n                        J[i-1, j-1][1, 2] = -b_df.loc[i, \'d_Ir_Q\' ]\n                        J[i-1, j-1][2, 0] = b_df.loc[i, \'Vr\']\n                        J[i-1, j-1][2, 1] = b_df.loc[i, \'Vm\']\n                    \n                    else:\n                        J[i-1, j-1][0, 0] =  B[i-1, j-1]\n                        J[i-1, j-1][0, 1] =  G[i-1, j-1]\n                        J[i-1, j-1][1, 0] =  G[i-1, j-1]\n                        J[i-1, j-1][1, 1] =  -B[i-1, j-1]\n\n                    delta_I[i-1,0][0,0] = b_df.loc[i,\'IR_k\']\n                    delta_I[i-1,0][1,0] = b_df.loc[i,\'IM_k\']\n                    delta_I[i-1,0][2,0] = pow(b_df.loc[i, \'Vmag\'],2)\n        \n    return delta_I, J '

# %%
def Jacobian(df, y_bus):
    b_df = data_df(df)
    G = np.real(y_bus)
    B = np.imag(y_bus)
    delta_I = np.zeros((nbus, 1, 3, 1))
    
    jac = pd.DataFrame(np.zeros((nbus, nbus)))

    for i in b_df.index:
        for j in b_df.index:
            J = np.zeros((2,2))
            J1 = np.zeros((3,3))
            if b_df.loc[i,"Bus_type"] != 3:
                if b_df.loc[i,"Bus_type"] == 1: # For PQ Bus
                    if i == j:
                        J[0, 0] = -b_df.loc[i, 'd_Im_Vr'] + B[i-1, i-1]
                        J[0, 1] = -b_df.loc[i, 'd_Im_Vm'] + G[i-1, i-1]
                        J[1, 0] = -b_df.loc[i, 'd_Ir_Vr'] + G[i-1, i-1]
                        J[1, 1] = -b_df.loc[i, 'd_Ir_Vm'] - B[i-1, i-1]
                        jac.loc[i-1, i-1] = J
                        print("J", J)

                    else:
                        J[0, 0] =  B[i-1, j-1]
                        J[0, 1] =  G[i-1, j-1]
                        J[1, 0] =  G[i-1, j-1]
                        J[1, 1] =  -B[i-1, j-1]
                        jac.loc[i-1, j-1] = J
                    
                    delta_I[i-1,0][0,0] = b_df.loc[i,'IR_k']
                    delta_I[i-1,0][1,0] = b_df.loc[i,'IM_k']
                   
                        
                else: #For PV Bus
                    if i == j:
                        J1[0, 0] = -b_df.loc[i, 'd_Im_Vr'] + B[i-1, i-1]
                        J1[0, 1] = -b_df.loc[i, 'd_Im_Vm'] + G[i-1, i-1]
                        J1[1, 0] = -b_df.loc[i, 'd_Ir_Vr'] + G[i-1, i-1]
                        J1[1, 1] = -b_df.loc[i, 'd_Ir_Vm'] - B[i-1, i-1]
                        J1[0, 2] = -b_df.loc[i, 'd_Im_Q' ]
                        J1[1, 2] = -b_df.loc[i, 'd_Ir_Q' ]
                        J1[2, 0] = b_df.loc[i, 'Vr']
                        J1[2, 1] = b_df.loc[i, 'Vm']
                        print("J1:", J1)
                        print(jac.loc[i-1, j-1])
                        jac.loc[i-1, j-1] = J1
                      
                    
                    else:
                        J1[0, 0] =  B[i-1, j-1]
                        J1[0, 1] =  G[i-1, j-1]
                        J1[1, 0] =  G[i-1, j-1]
                        J1[1, 1] =  -B[i-1, j-1]
                        jac.loc[i-1, j-1] = J1

                    delta_I[i-1,0][0,0] = b_df.loc[i,'IR_k']
                    delta_I[i-1,0][1,0] = b_df.loc[i,'IM_k']
                    delta_I[i-1,0][2,0] = pow(b_df.loc[i, 'Vmag'],2)
        
    return delta_I, jac

# %%
I, J = Jacobian(b_data, Y_bus())
# Out:
# J1: [[-83.3789734   18.75181861   0.90194271]
#  [ 18.61177514  83.59315449  -0.        ]
#  [  1.035        0.           0.        ]]
# 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\bpanthee\OneDrive - University of Vermont\Documents\University\DRS\Power FLow Solver\Power-Flow-Solver\Current_Injection.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> I, J = Jacobian(b_data, Y_bus())
#
# c:\Users\bpanthee\OneDrive - University of Vermont\Documents\University\DRS\Power FLow Solver\Power-Flow-Solver\Current_Injection.ipynb Cell 11 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X12sZmlsZQ%3D%3D?line=43'>44</a>     print("J1:", J1)
#      <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X12sZmlsZQ%3D%3D?line=44'>45</a>     print(jac.loc[i-1, j-1])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X12sZmlsZQ%3D%3D?line=45'>46</a>     jac.loc[i-1, j-1] = J1
#      <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X12sZmlsZQ%3D%3D?line=48'>49</a> else:
#      <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X12sZmlsZQ%3D%3D?line=49'>50</a>     J1[0, 0] =  B[i-1, j-1]
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1797, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1795     self._setitem_with_indexer_split_path(indexer, value, name)
#    1796 else:
# -> 1797     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2078, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    2075 self.obj._check_is_chained_assignment_possible()
#    2077 # actually do the set
# -> 2078 self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    2079 self.obj._maybe_update_cacher(clear=True, inplace=True)
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:393, in BaseBlockManager.setitem(self, indexer, value)
#     388 if _using_copy_on_write() and not self._has_no_reference(0):
#     389     # if being referenced -> perform Copy-on-Write and clear the reference
#     390     # this method is only called if there is a single block -> hardcoded 0
#     391     self = self.copy()
# --> 393 return self.apply("setitem", indexer=indexer, value=value)
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:986, in Block.setitem(self, indexer, value)
#     982         if lib.is_list_like(vi):
#     983             # checking lib.is_scalar here fails on
#     984             #  test_iloc_setitem_custom_object
#     985             casted = setitem_datetimelike_compat(values, len(vi), casted)
# --> 986     values[indexer] = casted
#     987 return self
#
# ValueError: setting an array element with a sequence.

# %%
J[1,1]
# Out:
# array([[-80.17571452,  17.91796472,   0.        ],
#        [ 17.35035862,  80.36976124,   0.        ],
#        [  0.        ,   0.        ,   0.        ]])

# %%
I[1,0]
# Out:
# array([[-0.97410628],
#        [ 0.20083835],
#        [ 0.        ]])

# %%
for k in b_data.index:
    print(k)
    np.linalg.inv(J[k-1,k-1])
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# c:\Users\bpanthee\OneDrive - University of Vermont\Documents\University\DRS\Power FLow Solver\Power-Flow-Solver\Current_Injection.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> for k in b_data.index:
#       <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     print(k)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bpanthee/OneDrive%20-%20University%20of%20Vermont/Documents/University/DRS/Power%20FLow%20Solver/Power-Flow-Solver/Current_Injection.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     np.linalg.inv(J[k-1,k-1])
#
# File <__array_function__ internals>:200, in inv(*args, **kwargs)
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:538, in inv(a)
#     536 signature = 'D->D' if isComplexType(t) else 'd->d'
#     537 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 538 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     539 return wrap(ainv.astype(result_t, copy=False))
#
# File c:\Users\bpanthee\AppData\Local\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
